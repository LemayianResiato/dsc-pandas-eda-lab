# %% [markdown]
# # Introduction:
# ## **Exploratory Data Analysis on Ames Housing Dataset**
#
# ### Objectives:
# 1. Load and clean the Ames Housing dataset using Pandas to prepare it for analysis.
# 2. Calculate and interpret key statistics,central tendency and dispersion measures, to understand home sale trends.
# 3. Create data subsets to focus on specific variables and features within the dataset.
# 4. Use data visualizations to explore patterns, trends, providing key insights for decision-making.
#
# ### Questions & Answers to Consider:
#
# 1. **Question:** What does the mean of a variable, tell us about the dataset?
#    **Answer:** The mean gives us an average value, helping us understand the typical house condition across all sales. For example, if the mean condition rating is average, it means houses in the dataset are generally in fair condition.
#
# 2. **Question:** Why is the standard deviation important when analyzing housing dataset?
#    **Answer:** The standard deviation shows how spread out the values are around the average. A higher standard deviation means there is more variety in house conditions, while a lower one means the data is more consistent.
#
# 3. **Question:** What does a right-skewed distribution in a variable suggest?
#    **Answer:** A right-skewed distribution suggests that most houses have lower condition ratings, with a few houses having significantly higher ratings. This could indicate that the majority of houses are in average or below-average condition.
#
# 4. **Question:** How can subsets of data help us make better business decisions?
#    **Answer:** By creating subsets, we can focus on specific groups of homes, like those within a certain price range or condition rating. This allows us to gain more targeted insights and make more informed decisions for pricing, renovations, or marketing.
#
# 5. **Question:** How can visualizations help in understanding trends or patterns in housing data?
#    **Answer:** Visualizations like histograms, scatter plots, or box plots make it easier to identify trends, such as the distribution of house prices or the relationship between home features and sales price. They provide a clearer way to communicate insights and spot peculiars or anything strange.

# %% [markdown]
# # Link to the data report:
#     https://docs.google.com/presentation/d/18QZaKsmSez0YaekBzKueX3yA7yp7RIx4g6pkLULX7_A/edit?usp=sharing

# %% [markdown]
# # EDA with Pandas - Cumulative Lab
#
# ## Introduction
#
# In this section, you've learned a lot about importing, cleaning up, analyzing (using descriptive statistics) and visualizing data. In this cumulative lab, you'll get a chance to practice all of these skills with the Ames Housing dataset, which contains information about home sales in Ames, Iowa between 2006 and 2010.
#
# ## Objectives
#
# You will be able to:
#
# * Practice loading data with pandas
# * Practice calculating measures of centrality and dispersion with pandas
# * Practice creating subsets of data with pandas
# * Practice using data visualizations to explore data, and interpreting those visualizations
# * Perform a full exploratory data analysis process to gain insight about a dataset

# %% [markdown]
# ## Your Task: Explore the Ames Housing Dataset with Pandas
#
# ![aerial photo of a neighborhood](images/neighborhood_aerial.jpg)
#
# Photo by <a href="https://unsplash.com/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Matt Donders</a> on <a href="/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
#
# Each record (row) in this dataset represents a home that was sold in Ames, IA.
#
# Each feature (column) in this dataset is some attribute of that home sale. You can view the file `data/data_description.txt` in this repository for a full explanation of all variables in this dataset — 80 columns in total.
#
# We are going to focus on the following features:
#
# **SalePrice**: `Sale price of the house in dollars`
#
# **TotRmsAbvGrd**: `Total rooms above grade (does not include bathrooms)`
#
# **OverallCond**: `Rates the overall condition of the house`
# ```
#        10	Very Excellent
#        9	 Excellent
#        8	 Very Good
#        7	 Good
#        6	 Above Average
#        5	 Average
#        4	 Below Average
#        3	 Fair
#        2	 Poor
#        1	 Very Poor
# ```
#
# **YrSold**: `Year Sold (YYYY)`
#
# **YearBuilt**: `Original construction date`
#
# **LandSlope**: `Slope of property`
# ```
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
# ```

# %% [markdown]
# ### Requirements
#
# In this lab you will use your data munging and visualization skills to conduct an exploratory analysis of the dataset.
#
# #### 1. Load the Dataset with Pandas
#
# Import pandas with the standard alias `pd` and load the data into a dataframe with the standard name `df`.
#
# #### 2. Explore Data Distributions
#
# Produce summary statistics, visualizations, and interpretive text describing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# #### 3. Explore Differences between Subsets
#
# Separate the data into subsets based on `OverallCond`, then demonstrate how this split impacts the distribution of `SalePrice`.
#
# #### 4. Explore Correlations
#
# Find the features that have the strongest positive and negative correlations with `SalePrice`, and produce plots representing these relationships.
#
# #### 5. Engineer and Explore a New Feature
#
# Create a new feature `Age`, which represents the difference between the year sold and the year built, and plot the relationship between the age and sale price.

# %% [markdown]
# ## 1. Load the Dataset with Pandas
#
# In the cell below, import:
# * `pandas` with the standard alias `pd`
# * `matplotlib.pyplot` with the standard alias `plt`
#
# And set `%matplotlib inline` so the graphs will display immediately below the cell that creates them.

# %%
# Displays directory or files that we have
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A9B-192F
#
#  Directory of C:\Users\Windows\Documents\Flatiron\dsc-pandas-eda-lab
#
# 01/24/2025  11:17 AM    <DIR>          .
# 01/21/2025  10:05 AM    <DIR>          ..
# 01/20/2025  07:03 PM               136 .canvas
# 01/20/2025  07:03 PM    <DIR>          .github
# 01/20/2025  07:03 PM                66 .gitignore
# 01/20/2025  07:06 PM    <DIR>          .ipynb_checkpoints
# 01/20/2025  07:03 PM                96 .learn
# 01/20/2025  07:03 PM             1,846 CONTRIBUTING.md
# 01/20/2025  07:03 PM    <DIR>          data
# 01/20/2025  07:03 PM    <DIR>          env
# 01/20/2025  07:03 PM    <DIR>          images
# 01/24/2025  11:17 AM           258,355 index.ipynb
# 01/20/2025  07:03 PM             1,354 LICENSE.md
# 01/20/2025  07:03 PM            11,766 README.md
# 01/20/2025  07:03 PM             4,857 splitter.py
#                8 File(s)        278,476 bytes
#                7 Dir(s)  158,646,427,648 bytes free

# %%
# Your code here
#Importing Pandas Library
import pandas as pd

#Importing Matplotlib Library
import matplotlib.pyplot as plt

#Importing the Numpy Library
import numpy as np


#Allows graph and visuals to be displayed
# %matplotlib inline

# %% [markdown]
# Now, use pandas to open the file located at `data/ames.csv` ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Specify the argument `index_col=0` in order to avoid creating an extra `Id` column. Name the resulting dataframe `df`.

# %%
# Your code here
# Loading our csv file
# index_col=0 omits the first Id column
df = pd.read_csv('data/ames.csv', index_col=0)

#Previewing the first 5 rows
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# The following code checks that you loaded the data correctly:

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %% [markdown]
# Inspect the contents of the dataframe:

# %%
# Run this cell without changes
df #Calling our DataFrame
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# Run this cell without changes
df.info() #Summary of our DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
# Statistical Summary of our DataFrame
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
#Checking the size of our DataFrame Rows and Columns
df.shape
# Out:
# (1460, 80)

# %%
#Calling the columns in our DataFrame
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
#Checking the number of columns we have
len(df.columns)
# Out:
# 80

# %%
#Checking if there missing values in our DataFrame
df.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
# Checking the missing values 
# True means  missing value (NaN).
# False means solid value.
df.isna()
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# Id
# 1          False     False        False    False   False   True     False
# 2          False     False        False    False   False   True     False
# 3          False     False        False    False   False   True     False
# 4          False     False        False    False   False   True     False
# 5          False     False        False    False   False   True     False
# ...          ...       ...          ...      ...     ...    ...       ...
# 1456       False     False        False    False   False   True     False
# 1457       False     False        False    False   False   True     False
# 1458       False     False        False    False   False   True     False
# 1459       False     False        False    False   False   True     False
# 1460       False     False        False    False   False   True     False
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
#Checking the duplicate values in our DataFrame
df.duplicated().sum()
#Our output shows we got no duplicate values
# Out:
# 0

# %%
# Allows us to see our text in general
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 2. Explore Data Distributions
#
# Write code to produce histograms showing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# Each histogram should have appropriate title and axes labels, as well as a black vertical line indicating the mean of the dataset. See the documentation for [plotting histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html), [customizing axes](https://matplotlib.org/stable/api/axes_api.html#axis-labels-title-and-legend), and [plotting vertical lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html#matplotlib.axes.Axes.axvline) as needed.

# %% [markdown]
# ### Sale Price
#
# In the cell below, produce a histogram for `SalePrice`.

# %%
# Your code here
# Calling the SalesPrice column
df['SalePrice'] = df["SalePrice"]

#Creating our plot
fig, ax = plt.subplots()

#Plotting our histogram
ax.hist(df["SalePrice"], color='violet', edgecolor='red')

# Plotting Black vertical line indicating the mean of our SalePrice.
ax.axvline(df["SalePrice"].mean(), color="black")

# Assigning out Title
ax.set_title("Our Sale Price Distribution")

# Labeling our x and y axes
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses");

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
#Finding the mean
SalePrice_mean = df['SalePrice'].mean()

#Finding the median
SalePrice_median = df['SalePrice'].median()

#Finding the standard deviation
SalePrice_standard_deviation = df['SalePrice'].std()

print("The SalePrice mean is: ", SalePrice_mean)
print("The SalePrice median is:", SalePrice_median)
print("The SalePrice standard deviation is:", SalePrice_standard_deviation)
# Out:
# The SalePrice mean is:  180921.19589041095
# The SalePrice median is: 163000.0
# The SalePrice standard deviation is: 79442.50288288662

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# ### Interpreting the measure of central tendancy above
#
# * The mean sale price represents the average sale price of houses in the dataset.
# * The median sale price represents the middle value when all sale prices are sorted in ascending order.
# * The standard deviation measures the dispersion or variability of the sale prices around the mean.
# * There are more houses with lower sale prices and fewer houses with higher sale prices.
# * The standard deviation shows a high degree of variability in sale prices.
# * This means that there is a wide range of sale prices in the dataset.

# %% [markdown]
# ### Total Rooms Above Grade
#
# In the cell below, produce a histogram for `TotRmsAbvGrd`.

# %%
# Your code here
# Calling the Total Rooms Above Grade column
df["TotRmsAbvGrd"] = df["TotRmsAbvGrd"]

#Creating our plot
fig, ax = plt.subplots()

#Plotting our histogram
ax.hist(df["TotRmsAbvGrd"], color='violet', edgecolor='red')

# Plotting Black vertical line indicating the mean of our Total Rooms Above Room.
ax.axvline(df["TotRmsAbvGrd"].mean(), color="black")

# Assigning out Title
ax.set_title("Our Total Rooms Above Grade Distribution")

# Labeling our x and y axes
ax.set_ylabel("Number of Houses")
ax.set_xlabel("Total Rooms Above Grade");

# %%
type(df['TotRmsAbvGrd']) #Checking the datatype
# Out:
# pandas.core.series.Series

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
#Finding the mean
Total_Rooms_Above_Grade_mean = df['TotRmsAbvGrd'].mean()

#Finding the median
Total_Rooms_Above_Grade_median = df['TotRmsAbvGrd'].median()

#Finding the standard deviation
Total_Rooms_Above_Grade_standard_deviation = df['TotRmsAbvGrd'].std()

print("The Total Rooms Above Grade mean is: ", Total_Rooms_Above_Grade_mean)
print("The Total Rooms Above Grade median is:", Total_Rooms_Above_Grade_median)
print("The Total Rooms Above Grade standard deviation is:", Total_Rooms_Above_Grade_standard_deviation)
# Out:
# The Total Rooms Above Grade mean is:  6.517808219178082
# The Total Rooms Above Grade median is: 6.0
# The Total Rooms Above Grade standard deviation is: 1.6253932905840505

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# ### Interpreting the measure of central tendancy above
# * The mean of 6.517808219178082 rooms suggests a typical house has slightly over 6 rooms above grade.
# * The median of 6.0 confirms the data is centered around this value, with a balanced distribution.
# * A standard deviation of 1.6253932905840505 indicates low variability, meaning most houses are close to the mean.
# * The slight right skew suggests the presence of a few larger homes with more rooms than average.

# %% [markdown]
# ### Overall Condition
#
# In the cell below, produce a histogram for `OverallCond`.

# %%
# Your code here
# Your code here
# Your code here
# Calling the SalesPrice column
df["OverallCond"] = df["OverallCond"]

#Creating our plot
fig, ax = plt.subplots()

#Plotting our histogram
ax.hist(df["OverallCond"], color='violet', edgecolor='red')

# Plotting Black vertical line indicating the mean of our TotRmsAbvGrd.
ax.axvline(df["OverallCond"].mean(), color="black")

# Assigning out Title
ax.set_title("Our Overall Condition Distribution")

# Labeling our x and y axes
ax.set_ylabel("Number of Houses")
ax.set_xlabel("Overall Condition");

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
# Finding the mean
Overall_Condition_mean = df['OverallCond'].mean()
# Finding the median
Overall_Condition_median = df['OverallCond'].median()
#Finding the standard deviation
Overall_Condition_standard_deviation = df['OverallCond'].std()

print("The Overall Condition mean is: ", Overall_Condition_mean)
print("The Overall Condition median is:", Overall_Condition_median)
print("The Overall Condition standard deviation is:", Overall_Condition_standard_deviation)
# Out:
# The Overall Condition mean is:  5.575342465753424
# The Overall Condition median is: 5.0
# The Overall Condition standard deviation is: 1.1127993367127316

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# ### Interpreting the measure of central tendancy above
# * The overall condition mean suggests houses are generally in fair condition, slightly above the middle of the rating.
# * The median of 5.0 indicates that half of the houses have a condition rating of 5 or below, and half are above.
# * The standard deviation reflects moderate variability, meaning condition ratings vary but are still close to the average.
# * The right skew in the distribution shows that there are more houses with lower condition ratings than higher ones.

# %% [markdown]
# ### Handling the missing values in our DataFrame

# %%
#Filling the missing values with Unknown so that we don't tamper with our data
df = df.fillna('Unknown')

# %%
df.isna().sum() #Checking for the missing values
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Age              0
# Length: 81, dtype: int64

# %% [markdown]
# ## 3. Explore Differences between Subsets
#
# As you might have noted in the previous step, the overall condition of the house seems like we should treat it as more of a categorical variable, rather than a numeric variable.
#
# One useful way to explore a categorical variable is to create subsets of the full dataset based on that categorical variable, then plot their distributions based on some other variable. Since this dataset is traditionally used for predicting the sale price of a house, let's use `SalePrice` as that other variable.
#
# In the cell below, create three variables, each of which represents a record-wise subset of `df` (meaning, it has the same columns as `df`, but only some of the rows).
#
# * `below_average_condition`: home sales where the overall condition was less than 5
# * `average_condition`: home sales where the overall condition was exactly 5
# * `above_average_condition`: home sales where the overall condition was greater than 5

# %%
# Replace None with appropriate code
below_average_condition = df[df['OverallCond'] < 5]
average_condition = df[df['OverallCond'] == 5]
above_average_condition = df[df['OverallCond'] > 5]

# %% [markdown]
# The following code checks that you created the subsets correctly:

# %%
# Run this cell without changes

# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551

# %% [markdown]
# The following code will produce a plot of the distributions of sale price for each of these subsets:

# %%
# Run this cell without changes

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="cyan",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="gray",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses")
ax.legend();

# %% [markdown]
# Interpret the plot above. What does it tell us about these overall condition categories, and the relationship between overall condition and sale price? Is there anything surprising?

# %% [markdown]
# # Replace None with appropriate text

# %% [markdown]
# ### i) Above Average Condition:
#
# * Houses above average sell for higher prices
# * The distribution is skewed towards higher values.
#
#
# ## ii) Average Condition:
#
# * Shows a broader range of sale prices compared to the other categories.
# * More Even Distribution: The distribution is more evenly spread across the price range.
# * The houses with average condition have the highest demand with a variability between an average price and the highest price
#
# ## iii) Below Average Condition:
#
# * Has the lowest sale prices.
# * The distribution is skewed towards lower values.
#
# ## Surprising Insight:
#
# * Overlap in Distributions: While the general trend is clear, there's some overlap between the distributions of different condition categories. For instance, some houses in "average condition" sell for prices comparable to those in "above average condition," and vice versa. This suggests that factors other than overall condition also play a role in determining sale price.
#
# ## There's a clear positive relationship between overall condition and sale price. Better condition generally leads to higher prices.
#
# ## Findings
# * Influence of Other Factors: The overlap between categories suggests that factors other than overall condition (location, size, age, amenities) play a crucial role in determining sale price.

# %% [markdown]
# ## 4. Explore Correlations
#
# To understand more about what features of these homes lead to higher sale prices, let's look at some correlations. We'll return to using the full `df`, rather than the subsets.
#
# In the cell below, print out both the name of the column and the Pearson correlation for the column that is ***most positively correlated*** with `SalePrice` (other than `SalePrice`, which is perfectly correlated with itself).
#
# We'll only check the correlations with some kind of numeric data type.
#
# You can import additional libraries, although it is possible to do this just using pandas.

# %%
# Calculate the correlation between all columns and 'SalePrice', then remove 'SalePrice' from the result.
correlation = df.corr()['SalePrice'].drop('SalePrice')

# Find the column with the highest positive correlation to 'SalePrice'.
max_corr_column = correlation.idxmax()

# Get the value of the highest positive correlation.
positive_corr_value = correlation.max()

# Print the column most positively correlated with 'SalePrice'.
print(f"Most positively correlated column: {max_corr_column}")

# Print the Maximum correlation value of the most positively correlated column.
print(f"Maximum correlation: {positive_corr_value}")
# Out:
# Most positively correlated column: OverallQual
# Maximum correlation: 0.7909816005838047

# %% [markdown]
# Now, find the ***most negatively correlated*** column:

# %%
# Your code here

# %%
# Find the column with the highest negative correlation to 'SalePrice'
min_corr_column = correlation.idxmin()

# Get the value of the highest negative correlation.
negative_corr_value = correlation.min()

# Print the column most negatively correlated with 'SalePrice'.
print(f"Most negatively correlated column: {min_corr_column}")

# Print the Minimum correlation value of the most positively correlated column.
print(f"Minimum correlation: {negative_corr_value}")
# Out:
# Most negatively correlated column: KitchenAbvGr
# Minimum correlation: -0.1359073708421417

# %%
# Selecting the numeric columns/ columns with numbers
numeric_columns = df.select_dtypes(['float64', 'int64'])

# Calculate correlations
total_correlation = numeric_columns.corr()['SalePrice']
print(total_correlation)
# Out:
# MSSubClass      -0.084284
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# MoSold           0.046432
# YrSold          -0.028923
# SalePrice        1.000000
# Age             -0.523350
# ...

# %% [markdown]
# Once you have your answer, edit the code below so that it produces a box plot of the relevant columns.

# %%
# Replace None with appropriate code

import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))

# Plot distribution of column with highest correlation
sns.boxplot(
    x=df[max_corr_column],
    y=df["SalePrice"],
    ax=ax1
)
# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df[min_corr_column],
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title('Distribution of highest positive correlation')
ax1.set_xlabel('Overall Condition')
ax1.set_ylabel("Sale Price")
ax2.set_title('Distribution of highest negative correlation')
ax2.set_xlabel('Kitchen Above Grade')
ax2.set_ylabel("Sale Price");

# %% [markdown]
# Interpret the results below. Consult `data/data_description.txt` as needed.

# %% [markdown]
# # Replace None with appropriate text
# ## Overall Condition and Sale Price:
#
# * Overall condition shows a strong positive correlation with sale price. Houses in better condition generally sell for higher prices.
# * The distribution of sale prices for each condition category (above average, average, below average) shows some overlap, indicating that other factors beyond condition also influence price.
#
# ## Kitchen Above Grade and Sale Price:
#
# * There is a negative correlation between Kitchen Above Grade and sale price. This suggests that properties with a higher number of kitchens above grade tend to have lower sale prices.
# * This could be due to factors like: multi-unit properties might have multiple kitchens, impacting overall desirability and potentially lowering the price.
# * Properties with multiple kitchens above grade might require more extensive renovations, making them less appealing to buyers.
#
# * Higher overall quality of a home tends to result in a higher sale price, with a strong positive correlation between the two.
# * Even with similar overall quality or age, house prices can vary significantly, with outliers showing both higher and lower-than-expected prices.
# * Older homes typically have lower sale prices, as their value depreciates over time, though there are still price variations for houses of the same age.
# * The number of kitchens above grade (KitchenAbvGr) is rarely more than one, and it has a weak negative correlation with sale price, suggesting it's not a major factor influencing home prices.

# %%
#loading the data_desscription/txt from the Data folder
with open ('data/data_description.txt','r') as f:
    data = f.read()   # f.readlines()

print(data)
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %% [markdown]
# ## 5. Engineer and Explore a New Feature
#
# Here the code is written for you, all you need to do is interpret it.
#
# We note that the data spans across several years of sales:

# %%
# Run this cell without changes
df["YrSold"].value_counts().sort_index()
# Out:
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: YrSold, dtype: int64

# %% [markdown]
# Maybe we can learn something interesting from the age of the home when it was sold. This uses information from the `YrBuilt` and `YrSold` columns, but represents a truly distinct feature.

# %%
# Run this cell without changes

# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price");

# %% [markdown]
# Interpret this plot below:

# %% [markdown]
# # Replace None with appropriate text
#
# * The majority of homes are either very new (0-15 years) or in the 30-60 year range, with fewer homes older than 100 years.
# * There is a weak negative correlation between the age of a home and its sale price, meaning older homes tend to have lower prices.
# * Homes that are not old have higher sale prices, though there are outliers where both old and new homes can be priced higher or lower than expected.
# * The age of the home has a  minor effect on the sale price, with some variation due to outliers.

# %% [markdown]
# # Recommendation
# ## Considerations
# * Buyers qualities and interests since they are the ones to decide
# * Geographic location, Saleprice, Year built also affect demand
# * Market trends and level of inflation
# * Condition of the homes

# %% [markdown]
# # Conclusion
# * Overall property condition is a key factor influencing sale price, with better condition generally leading to higher prices.
# * Gentle slopes are generally preferred, impacting construction costs and overall desirability.
# * Sale price is influenced by a combination of factors, including condition, location, size, amenities, and land features.

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed an exploratory data analysis of a popular dataset. You saw how to inspect the distributions of individual columns, subsets of columns, correlations, and new engineered features.
